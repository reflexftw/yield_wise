# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import mean_squared_error,r2_score

# %%
df = pd.read_csv("./Crop_Yield_Prediction.csv")

# %%
df.head()
# Out:
#    Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0        90          42         43    20.879744  82.002744  6.502985
# 1        85          58         41    21.770462  80.319644  7.038096
# 2        60          55         44    23.004459  82.320763  7.840207
# 3        74          35         40    26.491096  80.158363  6.980401
# 4        78          42         42    20.130175  81.604873  7.628473
#
#      Rainfall  Crop   Yield
# 0  202.935536  Rice    7000
# 1  226.655537  Rice    5000
# 2  263.964248  Rice    7000
# 3  242.864034  Rice    7000
# 4  262.717340  Rice  120000

# %%
crop_summary = pd.pivot_table(df, index="Crop", aggfunc="median")

# %%
crop_summary
# Out:
#               Humidity  Nitrogen  Phosphorus  Potassium    Rainfall  \
# Crop
# Apple        92.416541      24.0       136.5      200.0  112.979230
# Banana       80.223599     100.5        81.0       50.0  105.007750
# Blackgram    65.026723      41.0        67.0       19.0   68.293539
# ChickPea     16.658634      39.0        68.0       79.0   79.692282
# Coconut      94.960581      24.0        15.5       31.0  171.999922
# Coffee       57.648083     103.0        29.0       30.0  157.770963
# Cotton       80.010893     117.0        46.0       19.0   80.237095
# Grapes       81.724647      24.0       133.0      201.0   69.536186
# Jute         79.469205      78.0        46.0       40.0  175.590814
# KidneyBeans  21.348735      22.0        67.0       20.0  107.399392
# Lentil       64.094626      16.5        68.0       19.0   46.553255
# Maize        65.303845      76.0        48.5       20.0   83.471553
# Mango        50.281615      21.0        27.5       30.0   94.905973
# MothBeans    53.668190      22.0        48.5       20.0   51.182738
# MungBean     85.953767      22.0        47.0       20.0   49.028171
# Muskmelon    92.111116     100.0        18.0       50.0   24.721512
# Orange       91.963246      19.0        16.0       10.0  110.684073
# Papaya       92.681086      49.0        60.0       50.0  139.000698
# PigeonPeas   47.195180      20.0        69.5       20.0  154.310507
# Pomegranate  89.911979      18.0        20.0       40.0  107.588201
# Rice         82.189357      80.0        47.0       40.0  233.119859
# Watermelon   85.030605      99.0        17.5       50.5   50.671903
#
#              Temperature   Yield  pH_Value
# Crop
# Apple          22.628290  1525.0  5.885818
# Banana         27.443333  1500.0  5.994462
# Blackgram      29.655515  1500.0  7.165240
# ChickPea       18.878291  1700.0  7.356537
# Coconut        27.385317  1727.5  5.990709
# Coffee         25.656643  2125.0  6.798626
# Cotton         23.964997  1027.5  6.840957
# Grapes         23.018528  2335.0  6.001785
# Jute           24.971106   987.5  6.711500
# KidneyBeans    19.924037  2435.0  5.745283
# Lentil         24.946835  1450.0  6.954178
# Maize          22.844456  1875.0  6.259181
# Mango          31.300223  1010.0  5.743385
# MothBeans      28.370863  2750.0  7.219136
# MungBean       28.441673  2450.0  6.703890
# Muskmelon      28.851775  1979.0  6.353033
# Orange         22.901055   935.0  7.022614
# Papaya         33.262870  1700.0  6.740830
# PigeonPeas     28.931707  3500.0  5.690466
# Pomegranate    22.354425  2337.5  6.430715
# Rice           23.734837  2335.0  6.363804
# Watermelon     25.603965  2385.0  6.469926

# %%
new_crop_summary = df.drop(columns="Yield", axis=1)
new_crop_summary
# Out:
#       Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         Rainfall    Crop
# 0     202.935536    Rice
# 1     226.655537    Rice
# 2     263.964248    Rice
# 3     242.864034    Rice
# 4     262.717340    Rice
# ...          ...     ...
# 2195  177.774507  Coffee
# 2196  127.924610  Coffee
# 2197  173.322839  Coffee
# 2198  127.175293  Coffee
# 2199  140.937041  Coffee
#
# [2200 rows x 8 columns]

# %%
factors = df[['Nitrogen','Phosphorus','Potassium','Rainfall','Temperature','Humidity','pH_Value']]
target=df["Crop"]

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(factors, target, test_size=0.2, random_state=2)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
dt = DecisionTreeClassifier(criterion="entropy", random_state=2, max_depth=5)
dt.fit(Xtrain, Ytrain)
dt_pred = dt.predict(Xtest)
dt_accuracy_score = metrics.accuracy_score(Ytest, dt_pred)
print(dt_accuracy_score * 100)
dt_classification_report = metrics.classification_report(Ytest, dt_pred)
print(dt_classification_report)
# Out:
# 90.45454545454545
#               precision    recall  f1-score   support
#
#        Apple       1.00      1.00      1.00        13
#       Banana       1.00      1.00      1.00        17
#    Blackgram       0.59      1.00      0.74        16
#     ChickPea       1.00      1.00      1.00        21
#      Coconut       1.00      1.00      1.00        21
#       Coffee       1.00      1.00      1.00        22
#       Cotton       1.00      1.00      1.00        20
#       Grapes       1.00      1.00      1.00        18
#         Jute       0.76      1.00      0.86        28
#  KidneyBeans       0.00      0.00      0.00        14
#       Lentil       0.68      1.00      0.81        23
#        Maize       1.00      1.00      1.00        21
#        Mango       1.00      1.00      1.00        26
#    MothBeans       0.00      0.00      0.00        19
#     MungBean       1.00      1.00      1.00        24
#    Muskmelon       1.00      1.00      1.00        23
#       Orange       1.00      1.00      1.00        29
#       Papaya       1.00      0.84      0.91        19
#   PigeonPeas       0.62      1.00      0.77        18
#  Pomegranate       1.00      1.00      1.00        17
#         Rice       1.00      0.62      0.77        16
#   Watermelon       1.00      1.00      1.00        15
#
#     accuracy                           0.90       440
#    macro avg       0.85      0.88      0.86       440
# weighted avg       0.86      0.90      0.88       440
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\asus\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.naive_bayes import GaussianNB
GNB = GaussianNB()
GNB.fit(Xtrain,Ytrain)
GNB_pred = GNB.predict(Xtest)
GNB_accuracy_score = metrics.accuracy_score(Ytest, GNB_pred)
print(GNB_accuracy_score)
# Out:
# 0.990909090909091

# %%
df_col = crop_summary[['Nitrogen','Phosphorus','Potassium','Rainfall','Temperature','Humidity','pH_Value']]

# %%
for i in df_col:
    plt.figure(figsize = (15,6))
    sns.barplot(x='Crop', y=i, data= crop_summary, palette='hls', hue='Crop')
    plt.xticks(rotation = 90)
    plt.show()

# %%
df.head()
# Out:
#    Nitrogen  Phosphorus  Potassium  Temperature   Humidity  pH_Value  \
# 0        90          42         43    20.879744  82.002744  6.502985
# 1        85          58         41    21.770462  80.319644  7.038096
# 2        60          55         44    23.004459  82.320763  7.840207
# 3        74          35         40    26.491096  80.158363  6.980401
# 4        78          42         42    20.130175  81.604873  7.628473
#
#      Rainfall  Crop   Yield
# 0  202.935536  Rice    7000
# 1  226.655537  Rice    5000
# 2  263.964248  Rice    7000
# 3  242.864034  Rice    7000
# 4  262.717340  Rice  120000

# %%
X = crop_summary[['Nitrogen','Phosphorus','Potassium','Temperature','Humidity','pH_Value','Rainfall']]
Y = crop_summary['Yield']

# %%
crop_summary
# Out:
#               Humidity  Nitrogen  Phosphorus  Potassium    Rainfall  \
# Crop
# Apple        92.416541      24.0       136.5      200.0  112.979230
# Banana       80.223599     100.5        81.0       50.0  105.007750
# Blackgram    65.026723      41.0        67.0       19.0   68.293539
# ChickPea     16.658634      39.0        68.0       79.0   79.692282
# Coconut      94.960581      24.0        15.5       31.0  171.999922
# Coffee       57.648083     103.0        29.0       30.0  157.770963
# Cotton       80.010893     117.0        46.0       19.0   80.237095
# Grapes       81.724647      24.0       133.0      201.0   69.536186
# Jute         79.469205      78.0        46.0       40.0  175.590814
# KidneyBeans  21.348735      22.0        67.0       20.0  107.399392
# Lentil       64.094626      16.5        68.0       19.0   46.553255
# Maize        65.303845      76.0        48.5       20.0   83.471553
# Mango        50.281615      21.0        27.5       30.0   94.905973
# MothBeans    53.668190      22.0        48.5       20.0   51.182738
# MungBean     85.953767      22.0        47.0       20.0   49.028171
# Muskmelon    92.111116     100.0        18.0       50.0   24.721512
# Orange       91.963246      19.0        16.0       10.0  110.684073
# Papaya       92.681086      49.0        60.0       50.0  139.000698
# PigeonPeas   47.195180      20.0        69.5       20.0  154.310507
# Pomegranate  89.911979      18.0        20.0       40.0  107.588201
# Rice         82.189357      80.0        47.0       40.0  233.119859
# Watermelon   85.030605      99.0        17.5       50.5   50.671903
#
#              Temperature   Yield  pH_Value
# Crop
# Apple          22.628290  1525.0  5.885818
# Banana         27.443333  1500.0  5.994462
# Blackgram      29.655515  1500.0  7.165240
# ChickPea       18.878291  1700.0  7.356537
# Coconut        27.385317  1727.5  5.990709
# Coffee         25.656643  2125.0  6.798626
# Cotton         23.964997  1027.5  6.840957
# Grapes         23.018528  2335.0  6.001785
# Jute           24.971106   987.5  6.711500
# KidneyBeans    19.924037  2435.0  5.745283
# Lentil         24.946835  1450.0  6.954178
# Maize          22.844456  1875.0  6.259181
# Mango          31.300223  1010.0  5.743385
# MothBeans      28.370863  2750.0  7.219136
# MungBean       28.441673  2450.0  6.703890
# Muskmelon      28.851775  1979.0  6.353033
# Orange         22.901055   935.0  7.022614
# Papaya         33.262870  1700.0  6.740830
# PigeonPeas     28.931707  3500.0  5.690466
# Pomegranate    22.354425  2337.5  6.430715
# Rice           23.734837  2335.0  6.363804
# Watermelon     25.603965  2385.0  6.469926

# %%
#correlation matrix
new_df = df[['Nitrogen','Phosphorus','Potassium','Temperature','Humidity','pH_Value','Rainfall','Yield']]
corr_matrix = new_df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
#scatter_plot

features = ['Nitrogen','Phosphorus','Potassium','Temperature','Humidity','pH_Value','Rainfall']
for feature in features:
    plt.figure(figsize=(8, 6))
    sns.scatterplot(data=df, x=crop_summary[feature], y=crop_summary['Yield'])
    plt.grid(True)
    plt.show()


# sns.scatterplot(data=crop_summary, x='Rainfall', y='Yield')
# plt.title('Rainfall vs. Yield', fontsize=14)
# plt.xlabel('Rainfall', fontsize=12)
# plt.ylabel('Yield', fontsize=12)
# plt.grid(True)

# plt.figure(figsize=(8,6))
# sns.scatterplot(data=crop_summary, x='Nitrogen', y='Yield')
# plt.title('Nitrogen vs. Yield', fontsize=14)
# plt.xlabel('Nitrogen', fontsize=12)
# plt.ylabel('Yield', fontsize=12)
# plt.grid(True)

# %%
# from sklearn.preprocessing import LabelEncoder
# for col in crop_summary:
#     le = LabelEncoder()
#     crop_summary[col] = le.fit_transform(crop_summary[col])

# crop_summary.head()

# %%
# from sklearn.feature_selection import chi2
# X = crop_summary[['Nitrogen','Phosphorus','Potassium','Temperature','Humidity','pH_Value','Rainfall']]
# y = crop_summary['Yield']

# chi_scores = chi2(X,y)
# chi_values

# chi_values = pd.Series(chi_scores[0], index=X.columns)
# chi_values.plot.bar()

# %%
model_rf = RandomForestRegressor()

# %%
model_lr = LinearRegression()

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2, random_state=42)

# %%
model_rf.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
df['Crop'].value_counts()
# Out:
# Crop
# Rice           100
# Maize          100
# ChickPea       100
# KidneyBeans    100
# PigeonPeas     100
# MothBeans      100
# MungBean       100
# Blackgram      100
# Lentil         100
# Pomegranate    100
# Banana         100
# Mango          100
# Grapes         100
# Watermelon     100
# Muskmelon      100
# Apple          100
# Orange         100
# Papaya         100
# Coconut        100
# Cotton         100
# Jute           100
# Coffee         100
# Name: count, dtype: int64

# %%
Y_pred_rf = model_rf.predict(X_test)
r2 = r2_score(Y_test, Y_pred_rf)
print(r2)
# Out:
# -0.974060928231925

# %%
mse = mean_squared_error(Y_test,Y_pred_rf)

# %%
mse
# Out:
# np.float64(689720.2272500002)

# %%
model_lr = LinearRegression()

# %%
model_lr.fit(X_train, Y_train)
Y_pred_lr = model_lr.predict(X_test)
r2_lr = r2_score(Y_test, Y_pred_lr)
print(r2_lr)
# Out:
# -2.122258987380979

# %%
# Y_pred_lr = model_lr.predict(X_test)

# plt.figure(figsize=(5,5))
# plt.scatter(Y_test,Y_pred_lr, color='blue')

results = pd.DataFrame({'y_test': Y_test, 'y_pred': Y_pred_lr})

# Scatter Plot of y_test vs. y_pred
plt.figure(figsize=(8, 6))
sns.regplot(x='y_test', y='y_pred', data=results, 
            scatter_kws={'s': 50, 'color': 'blue'}, 
            line_kws={'color': 'red', 'label': 'Regression Line'})
plt.title('Scatter Plot of Predicted vs. Actual Values', fontsize=14)
plt.xlabel('Actual Values (y_test)', fontsize=12)
plt.ylabel('Predicted Values (y_pred)', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %%
mse_lr = mean_squared_error(Y_test, Y_pred_lr)

# %%
mse_lr
# Out:
# np.float64(1090890.9383250605)

# %%
mse_all = [mse, mse_lr]

# %%
algorithm_models = ['Random Forest Regression','Linear Regression']

# %%
plt.figure(figsize=(6,6))
sns.barplot(x=algorithm_models, y=mse_all, palette='Spectral', hue=algorithm_models)
plt.xlabel('Algorithm models')
plt.ylabel('MSE')

plt.show()
